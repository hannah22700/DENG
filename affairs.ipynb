# %%
import requests
import pandas as pd
import numpy as np

# Beispiel
# https://api.openparldata.ch/v1/affairs/?search=(Klima | Umwelt) & Schweiz&search_mode=boolean&limit=10 → Complex query with grouping

BASE_URL = "https://api.openparldata.ch/v1"

def fetch_affairs(search_term: str = "AI", limit: int = 100, offset: int = 0):
    response = requests.get(
        f"{BASE_URL}/affairs",
        params={
            "search": search_term,
            "search_mode": "partial",
            "sort_by": "-begin_date",
            "limit": limit,
            "offset": offset
        }
    )
    print(response.url)        # shows the exact URL being called
    # print(response.status_code)
    # print(response.json()) 
    response.raise_for_status()
    return response.json()

offset = 0
limit = 1000
all_affairs = []

while True:
    data = fetch_affairs(search_term="Künstliche Intelligenz", limit=limit, offset=offset)
    items = data.get("data", [])
    all_affairs.extend(items)
    
    if not data["meta"]["has_more"]:  # ← correct key
        break
    offset += limit

# JSON → DataFrame
df = pd.json_normalize(all_affairs)


# Englische Types  
types = np.unique(df["type_harmonized.en"].dropna())

print(f"Total fetched: {len(all_affairs)}")
print(f"Types: {types}")

df["title.de"].dropna()
# Out:
# https://api.openparldata.ch/v1/affairs/?search=K%C3%BCnstliche+Intelligenz&search_mode=partial&sort_by=-begin_date&limit=1000&offset=0
# Total fetched: 124
# Types: ['Interpellation' 'Motion' 'Parliamentary initiative' 'Petition'
#  'Postulate' 'Question' 'Question time']
# 0      Studie zu einem Paradigmenwechsel im Steuersys...
# 1      Informationsdefizit, künstliche Intelligenz un...
# 2      Einsatz von Künstlicher Intelligenz in der Ver...
# 3      Förderung der agilen Verwaltung durch den Eins...
# 4      Künstliche Intelligenz (KI), Cloud-Computing u...
#                              ...
# 119    Die Schweiz als führendes Land im Bereich der ...
# 120    Kompetenzzentrum für künstliche Intelligenz in...
# 121    Künstliche Intelligenz: Ist der Kanton Bern pr...
# 122    Wie kann die Schweiz an der Forschung zu künst...
# 123    Bericht zu Chancen und Risiken von künstlicher...
# Name: title.de, Length: 124, dtype: str
